# %% [markdown]
# #mixed-integer non-linear integers

# %% [markdown]
# Problem
# Max: x+xy
#
# Constraints:
#
# -x+2xy <= 8
#
# 2x+y <= 14
#
# 2x-y <= 10
#
# 0 <= x<= 10
#
# 0 <= y<= 10
#
# x integer

# %% [markdown]
# #Installation

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.1.0-1/Mambaforge-23.1.0-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:16
# 🔁 Restarting kernel...

# %%
# !conda install pyscipopt
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - pyscipopt
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ampl-mp-3.1.0              |    h2cc385e_1006         1.1 MB  conda-forge
#     boltons-23.0.0             |     pyhd8ed1ab_0         296 KB  conda-forge
#     ca-certificates-2023.5.7   |       hbcca054_0         145 KB  conda-forge
#     certifi-2023.5.7           |     pyhd8ed1ab_0         149 KB  conda-forge
#     conda-23.3.1               |  py310hff52083_0         941 KB  conda-forge
#     cppad-20230000.0           |       hcb278e6_0         444 KB  conda-forge
#     gmp-6.2.1                  |       h58526e2_0         806 KB  conda-forge
#     ipopt-3.14.12              |       hf9e1ecf_0         999 KB  conda-forge
#     jsonpatch-1.32             |     pyhd8ed1ab_0          14 KB  conda-forge
#     jsonpointer-2.0            |             py_0           9 KB  conda-forge
#     libblas-3.9.0              |16_linux64_openblas          13 KB  conda-forge
#     libgfortran-ng-12.2.0      |      h69a702a_19          22 KB  conda-forge
#     libgfortran5-12.2.0        |      h337968e_19         1.8 MB  conda-forge
#     libhwloc-2.9.1             |       hd6dc26d_0         2.5 MB  conda-forge
#     liblapack-3.9.0            |16_linux64_openblas          13 KB  conda-forge
#     libopenblas-0.3.21         |pthreads_h78a6416_3        10.1 MB  conda-forge
#     metis-5.1.0                |    h58526e2_1006         4.1 MB  conda-forge
#     mumps-include-5.2.1        |      ha770c72_11          23 KB  conda-forge
#     mumps-seq-5.2.1            |      h2104b81_11         3.3 MB  conda-forge
#     openssl-3.1.0              |       hd590300_3         2.5 MB  conda-forge
#     packaging-23.1             |     pyhd8ed1ab_0          45 KB  conda-forge
#     pyscipopt-4.3.0            |  py310heca2aa9_0         594 KB  conda-forge
#     scip-8.0.3                 |       h4a32fe0_2         8.4 MB  conda-forge
#     scotch-6.0.9               |       hb2e6521_2         1.3 MB  conda-forge
#     tbb-2021.9.0               |       hf52228f_0         1.5 MB  conda-forge
#     unixodbc-2.3.10            |       h583eb01_0         296 KB  conda-forge
#     zlib-1.2.13                |       h166bdaf_4          92 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        41.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   ampl-mp            conda-forge/linux-64::ampl-mp-3.1.0-h2cc385e_1006
#   boltons            conda-forge/noarch::boltons-23.0.0-pyhd8ed1ab_0
#   cppad              conda-forge/linux-64::cppad-20230000.0-hcb278e6_0
#   gmp                conda-forge/linux-64::gmp-6.2.1-h58526e2_0
#   ipopt              conda-forge/linux-64::ipopt-3.14.12-hf9e1ecf_0
#   jsonpatch          conda-forge/noarch::jsonpatch-1.32-pyhd8ed1ab_0
#   jsonpointer        conda-forge/noarch::jsonpointer-2.0-py_0
#   libblas            conda-forge/linux-64::libblas-3.9.0-16_linux64_openblas
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-12.2.0-h69a702a_19
#   libgfortran5       conda-forge/linux-64::libgfortran5-12.2.0-h337968e_19
#   libhwloc           conda-forge/linux-64::libhwloc-2.9.1-hd6dc26d_0
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-16_linux64_openblas
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.21-pthreads_h78a6416_3
#   metis              conda-forge/linux-64::metis-5.1.0-h58526e2_1006
#   mumps-include      conda-forge/linux-64::mumps-include-5.2.1-ha770c72_11
#   mumps-seq          conda-forge/linux-64::mumps-seq-5.2.1-h2104b81_11
#   packaging          conda-forge/noarch::packaging-23.1-pyhd8ed1ab_0
#   pyscipopt          conda-forge/linux-64::pyscipopt-4.3.0-py310heca2aa9_0
#   scip               conda-forge/linux-64::scip-8.0.3-h4a32fe0_2
#   scotch             conda-forge/linux-64::scotch-6.0.9-hb2e6521_2
#   tbb                conda-forge/linux-64::tbb-2021.9.0-hf52228f_0
#   unixodbc           conda-forge/linux-64::unixodbc-2.3.10-h583eb01_0
#   zlib               conda-forge/linux-64::zlib-1.2.13-h166bdaf_4
#
# The following packages will be UPDATED:
#
#   ca-certificates                      2022.12.7-ha878542_0 --> 2023.5.7-hbcca054_0
#   certifi                            2022.12.7-pyhd8ed1ab_0 --> 2023.5.7-pyhd8ed1ab_0
#   conda                              23.1.0-py310hff52083_0 --> 23.3.1-py310hff52083_0
#   openssl                                  3.1.0-h0b41bf4_0 --> 3.1.0-hd590300_3
#
#
#
# Downloading and Extracting Packages
# boltons-23.0.0       | 296 KB    | :   0% 0/1 [00:00<?, ?it/s]
# certifi-2023.5.7     | 149 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
# tbb-2021.9.0         | 1.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# ampl-mp-3.1.0        | 1.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# packaging-23.1       | 45 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# liblapack-3.9.0      | 13 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# libblas-3.9.0        | 13 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# conda-23.3.1         | 941 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# cppad-20230000.0     | 444 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# zlib-1.2.13          | 92 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# mumps-seq-5.2.1      | 3.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.0        | 2.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# unixodbc-2.3.10      | 296 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# scip-8.0.3           | 8.4 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jsonpatch-1.32       | 14 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mumps-include-5.2.1  | 23 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-ng-12.2. | 22 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scotch-6.0.9         | 1.3 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# certifi-2023.5.7     | 149 KB    | :  11% 0.10751855521941424/1 [00:00<00:01,  1.47s/it]
#
#
# boltons-23.0.0       | 296 KB    | :   5% 0.054111360281125426/1 [00:00<00:02,  3.07s/it]
#
# tbb-2021.9.0         | 1.5 MB    | :   1% 0.010723460515163315/1 [00:00<00:15, 16.17s/it]
#
#
#
# packaging-23.1       | 45 KB     | :  36% 0.3554167208989544/1 [00:00<00:00,  2.01it/s]
#
#
#
#
# liblapack-3.9.0      | 13 KB     | : 100% 1.0/1 [00:00<00:00,  4.37it/s]
#
#
#
#
#
# libblas-3.9.0        | 13 KB     | : 100% 1.0/1 [00:00<00:00,  3.99it/s]
#
# tbb-2021.9.0         | 1.5 MB    | :  80% 0.8042595386372487/1 [00:00<00:00,  3.62it/s]
# certifi-2023.5.7     | 149 KB    | : 100% 1.0/1 [00:00<00:00,  4.21it/s]
# certifi-2023.5.7     | 149 KB    | : 100% 1.0/1 [00:00<00:00,  4.21it/s]
#
#
#
# packaging-23.1       | 45 KB     | : 100% 1.0/1 [00:00<00:00,  2.01it/s]
#
#
#
#
#
#
#
# cppad-20230000.0     | 444 KB    | :   4% 0.03607578910283934/1 [00:00<00:07,  7.83s/it]
#
#
#
#
#
#
# conda-23.3.1         | 941 KB    | :   2% 0.01699687325585979/1 [00:00<00:16, 17.17s/it]
#
#
#
#
#
#
#
#
#
# mumps-seq-5.2.1      | 3.3 MB    | :   0% 0.0047662018572594686/1 [00:00<01:00, 61.19s/it]
#
#
#
#
#
#
#
#
# zlib-1.2.13          | 92 KB     | :  17% 0.1741144964346061/1 [00:00<00:01,  1.71s/it]
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | :   0% 0.0015489208557598652/1 [00:00<03:23, 203.45s/it]
#
#
#
#
# liblapack-3.9.0      | 13 KB     | : 100% 1.0/1 [00:00<00:00,  4.37it/s]
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.0        | 2.5 MB    | :   1% 0.006164165296246007/1 [00:00<00:54, 55.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# unixodbc-2.3.10      | 296 KB    | :   5% 0.05400808275261898/1 [00:00<00:06,  7.07s/it]
#
#
#
#
#
#
#
#
#
# mumps-seq-5.2.1      | 3.3 MB    | :  40% 0.3955947541525359/1 [00:00<00:00,  1.27it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# scip-8.0.3           | 8.4 MB    | :   0% 0.001866762131618124/1 [00:00<03:35, 215.72s/it]
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | :  15% 0.15489208557598652/1 [00:00<00:01,  2.10s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jsonpatch-1.32       | 14 KB     | : 100% 1.0/1 [00:00<00:00,  2.33it/s]
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.0        | 2.5 MB    | :  70% 0.6965506784757988/1 [00:00<00:00,  2.04it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mumps-include-5.2.1  | 23 KB     | :  68% 0.6809076552240046/1 [00:00<00:00,  1.44it/s]
#
#
#
#
#
#
#
#
#
# mumps-seq-5.2.1      | 3.3 MB    | :  95% 0.9532403714518938/1 [00:00<00:00,  2.63it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# scip-8.0.3           | 8.4 MB    | :  24% 0.23521202858388363/1 [00:00<00:01,  1.64s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scotch-6.0.9         | 1.3 MB    | :   1% 0.011620352639119395/1 [00:00<00:44, 44.56s/it]
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | :  32% 0.31752877543077235/1 [00:00<00:00,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-ng-12.2. | 22 KB     | :  72% 0.7159587484705471/1 [00:00<00:00,  1.35it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# boltons-23.0.0       | 296 KB    | : 100% 1.0/1 [00:00<00:00,  1.79it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# scip-8.0.3           | 8.4 MB    | :  44% 0.43868910093025915/1 [00:00<00:00,  1.01s/it]
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | :  52% 0.5188884866795548/1 [00:00<00:00,  1.17it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# libblas-3.9.0        | 13 KB     | : 100% 1.0/1 [00:00<00:00,  3.99it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# scip-8.0.3           | 8.4 MB    | :  64% 0.6421661732766347/1 [00:00<00:00,  1.28it/s]
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | :  70% 0.6970143850919392/1 [00:00<00:00,  1.35it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# scip-8.0.3           | 8.4 MB    | :  83% 0.8325759107016834/1 [00:00<00:00,  1.45it/s]
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | :  97% 0.9696244557056756/1 [00:00<00:00,  1.76it/s]
#
# tbb-2021.9.0         | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  3.62it/s]
#
#
#
#
#
#
#
#
# zlib-1.2.13          | 92 KB     | : 100% 1.0/1 [00:00<00:00,  1.17it/s]
#
#
#
#
#
#
#
#
# zlib-1.2.13          | 92 KB     | : 100% 1.0/1 [00:00<00:00,  1.17it/s]
#
#
#
#
#
#
#
# cppad-20230000.0     | 444 KB    | : 100% 1.0/1 [00:01<00:00,  1.08s/it]
#
#
#
#
#
#
#
# cppad-20230000.0     | 444 KB    | : 100% 1.0/1 [00:01<00:00,  1.08s/it]
#
#
# ampl-mp-3.1.0        | 1.1 MB    | : 100% 1.0/1 [00:01<00:00,  1.16s/it]
#
#
# ampl-mp-3.1.0        | 1.1 MB    | : 100% 1.0/1 [00:01<00:00,  1.16s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# unixodbc-2.3.10      | 296 KB    | : 100% 1.0/1 [00:01<00:00,  1.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# unixodbc-2.3.10      | 296 KB    | : 100% 1.0/1 [00:01<00:00,  1.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# jsonpatch-1.32       | 14 KB     | : 100% 1.0/1 [00:01<00:00,  2.33it/s]
#
#
#
#
#
#
# conda-23.3.1         | 941 KB    | : 100% 1.0/1 [00:01<00:00,  1.50s/it]
#
#
#
#
#
#
# conda-23.3.1         | 941 KB    | : 100% 1.0/1 [00:01<00:00,  1.50s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mumps-include-5.2.1  | 23 KB     | : 100% 1.0/1 [00:01<00:00,  1.86s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mumps-include-5.2.1  | 23 KB     | : 100% 1.0/1 [00:01<00:00,  1.86s/it]
#
#
#
#
#
#
#
#
#
#
#
# openssl-3.1.0        | 2.5 MB    | : 100% 1.0/1 [00:01<00:00,  2.04it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-ng-12.2. | 22 KB     | : 100% 1.0/1 [00:01<00:00,  1.95s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-ng-12.2. | 22 KB     | : 100% 1.0/1 [00:01<00:00,  1.95s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scotch-6.0.9         | 1.3 MB    | : 100% 1.0/1 [00:02<00:00,  1.97s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scotch-6.0.9         | 1.3 MB    | : 100% 1.0/1 [00:02<00:00,  1.97s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
# mumps-seq-5.2.1      | 3.3 MB    | : 100% 1.0/1 [00:02<00:00,  2.63it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# scip-8.0.3           | 8.4 MB    | : 100% 1.0/1 [00:03<00:00,  1.45it/s]
#
#
#
#
#
#
#
#
#
#
# libopenblas-0.3.21   | 10.1 MB   | : 100% 1.0/1 [00:05<00:00,  1.76it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done

# %% [markdown]
# #mixed-integer non-linear integers

# %% [markdown]
# #Solution

# %%
from pyscipopt import Model

model= Model('example')

#creating Variable

x=model.addVar('x', vtype='INTEGER')
y=model.addVar('y')
z=model.addVar('z')

#objective

model.setObjective(z, sense='maximize')

#Constraints
model.addCons(z==x+x*y)
model.addCons(-x+2*x*y <= 8)
model.addCons(2*x+y <= 14)
model.addCons(2*x-y <= 10)


model.optimize()

solution=model.getBestSol()

print('x:', solution[x])
print('y:', solution[y])
# Out:
# x: 5.0
# y: 1.3
